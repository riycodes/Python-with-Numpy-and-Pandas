# %%
fruits = ["banana", "apple", "cherry"]

# %% [markdown]
# for each of the fruit in the list of fruits, print each fruit

# %%
for fruit in fruits:
    print(fruit)
# Out:
# banana
# apple
# cherry

# %%
i = 0
for number in range(1,6):
    i = number + i
    print(i)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
i = 0
for number in range(1,6):
    i = number + i
print(i)
print(i)
# Out:
# 15
# 15

# %%
def addition(number):
    print(number * number)
result = addition(2)
print(result)
# Out:
# 4
# None

# %%
def addition(number):
    return(number * number)
print(addition(2))
# Out:
# 4

# %%
def addition(no):
    return(no * 2)
result = addition(2)
print(result)
print(addition(4))
# Out:
# 4
# 8

# %%
def count_survivors(survival_values):
    count = 0
    for manoj in survival_values:
        if manoj == 1:
           count = count + 1
    return count
print(count_survivors([0,1,1,1,1,1,0,1,0]))
# Out:
# 5

# %%
for i in range(3):
    print(i+1)
# Out:
# 1
# 2
# 3

# %%
total = 0
for n in [2,4,6]:
    total = total + n
    print(total)
# Out:
# 2
# 6
# 12

# %%
total = 0
for n in [2,4,6]:
    total = total + n
print(total)
# Out:
# 12

# %%
def add(a, b):
    return a + b

result = add(3, 4)
print(result)
# Out:
# 7

# %%
def show(x):
    print(x * 2)

print(show(5))
# Out:
# 10
# None

# %%
def total_price(totalListOfPrices):
    sum = 0
    for price in totalListOfPrices:
        sum = sum + price
    return(sum)
print(total_price([100, 250, 75]))
# Out:
# 425

# %%
def count_above(list, threshold):
    count = 0
    for numbers in list:
          if numbers > threshold:
              count = count + 1
    return count
print(count_above([10, 50, 90, 30], 40))
# Out:
# 2

# %%
city = "Kathmandu"
temperature = str(25)
print(city + " is " + temperature +  " degrees today ")
# Out:
# Kathmandu is 25 degrees today

# %%
subjects = ["math", "science", "english"]
print((subjects[0]))
# Out:
# math

# %%
marks = 72
if marks >= 40:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
for numbers in range(1,6):
    print(numbers)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
prices = [120, 50, 80]
for price in prices:
    print(price)
# Out:
# 120
# 50
# 80

# %%
def double(number):
    return(number * 2)
result = double(3)
print(result)
# Out:
# 6

# %%
def add(a, b):
    return a + b

print(add(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 def add(a, b):
#       2     return a + b
# ----> 4 print(add(5))
#
# TypeError: add() missing 1 required positional argument: 'b'

# %%
def add(a, b):
    return a + b

print(add(5,4))
# Out:
# 9

# %%
def grade(mark):          
    if mark >= 40:
        return "Pass"     
    else:
        return "Fail"

for mark in marks_list:
    print(mark, grade(mark))
# Out:
# 85 Pass
# 38 Fail
# 67 Pass
# 91 Pass
# 54 Pass

# %% [markdown]
# Done for M0
